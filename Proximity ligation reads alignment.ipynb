# %% [markdown]
# In this walkthrough, we will understand how to align Dovetail's proximilty ligation reads to the human reference genome GRCh38. Let's first begin with BWA index for human genome GRCh38.

# %%
# !mkdir -p GRCh38 && cd GRCh38
# !wget https://dovetail-public-data.s3-us-west-2.amazonaws.com/hg38_data/GRCh38.p12.dict
# !wget https://dovetail-public-data.s3-us-west-2.amazonaws.com/hg38_data/GRCh38.p12.fa
# !wget https://dovetail-public-data.s3-us-west-2.amazonaws.com/hg38_data/GRCh38.p12.fa.amb
# !wget https://dovetail-public-data.s3-us-west-2.amazonaws.com/hg38_data/GRCh38.p12.fa.ann
# !wget https://dovetail-public-data.s3-us-west-2.amazonaws.com/hg38_data/GRCh38.p12.fa.sa
# !wget https://dovetail-public-data.s3-us-west-2.amazonaws.com/hg38_data/GRCh38.p12.fa.bwt
# !wget https://dovetail-public-data.s3-us-west-2.amazonaws.com/hg38_data/GRCh38.p12.fa.pac
# !wget https://dovetail-public-data.s3-us-west-2.amazonaws.com/hg38_data/GRCh38.p12.fa.fai
# !wget https://dovetail-public-data.s3-us-west-2.amazonaws.com/hg38_data/GRCh38.p12.genome
# !cd ../
# Out:
# --2020-06-25 12:40:47--  https://dovetail-public-data.s3-us-west-2.amazonaws.com/hg38_data/GRCh38.p12.dict
# Resolving dovetail-public-data.s3-us-west-2.amazonaws.com (dovetail-public-data.s3-us-west-2.amazonaws.com)... 52.218.253.153
# Connecting to dovetail-public-data.s3-us-west-2.amazonaws.com (dovetail-public-data.s3-us-west-2.amazonaws.com)|52.218.253.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2363 (2.3K) [binary/octet-stream]
# Saving to: ‘GRCh38.p12.dict’
#
# GRCh38.p12.dict     100%[===================>]   2.31K  --.-KB/s    in 0.001s
#
# 2020-06-25 12:40:47 (2.04 MB/s) - ‘GRCh38.p12.dict’ saved [2363/2363]
#
# --2020-06-25 12:40:47--  https://dovetail-public-data.s3-us-west-2.amazonaws.com/hg38_data/GRCh38.p12.fa
# Resolving dovetail-public-data.s3-us-west-2.amazonaws.com (dovetail-public-data.s3-us-west-2.amazonaws.com)... 52.218.253.153
# ...

# %% [markdown]
# Now, we will download downsampled fastq files for this demo.

# %%
# !mkdir -p reads && cd reads
# !wget https://dovetail-public-data.s3-us-west-2.amazonaws.com/Micro_subset/MicroC_100k_R1.fastq.gz
# !wget https://dovetail-public-data.s3-us-west-2.amazonaws.com/Micro_subset/MicroC_100k_R2.fastq.gz

# %% [markdown]
# We will use bwa to align reads to the reference genome. While running bwa, we will use Hi-C specific parameters `-5SP`. These options skip mate resuce and read pairing as proximity ligation reads don't follow normal distribution for read pair separation like traditional mate pair libraries. The command to run
